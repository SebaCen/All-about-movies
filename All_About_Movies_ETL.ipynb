# %% [markdown]
# #                        🎞🎬📽🎥            ⛏🔧🔨

# %% [markdown]
# # Proceso de ETL para el siguiente dataset:

# %% [markdown]
# https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset

# %% [markdown]
# ### Se instalan las librerías necesarias

# %%
# !pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /root/venv/lib/python3.9/site-packages (2023.4.0)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from fastparquet) (21.3)
# Requirement already satisfied: cramjam>=2.3 in /root/venv/lib/python3.9/site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: pandas>=1.5.0 in /root/venv/lib/python3.9/site-packages (from fastparquet) (2.0.2)
# Requirement already satisfied: fsspec in /root/venv/lib/python3.9/site-packages (from fastparquet) (2023.6.0)
# Requirement already satisfied: numpy>=1.20.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from fastparquet) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2022.5)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2022.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging->fastparquet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Se importan las librerías que vamos a utilizar

# %%
import pandas as pd
import numpy as np
import json
import ast
import fastparquet
import seaborn as sns

# %% [markdown]
# # -------------------------------------------------

# %% [markdown]
# # Extracción

# %% [markdown]
# ### Se lee el archivo "movies" y se crea el dataframe

# %%
movies_original = pd.read_csv('/work/movies_dataset.csv')
# Out:
# /tmp/ipykernel_1120/421480135.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_original = pd.read_csv('/work/movies_dataset.csv')

# %% [markdown]
# ### Vista preliminar del dataframe movies

# %%
movies_original
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %% [markdown]
# ### Se carga el archivo de "credits" a un nuevo dataframe

# %%
credits = pd.read_csv('/work/credits.csv')

# %% [markdown]
# ### Vista preliminar del dataframe credits

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
# [45476 rows x 3 columns]

# %% [markdown]
# # -----------------------------------------------

# %% [markdown]
# # Transformación

# %% [markdown]
# ## Se acondiciona movies

# %% [markdown]
# ### Cantidad de filas y columnas del dataframe

# %%
movies_original.shape
# Out:
# (45466, 24)

# %% [markdown]
# ### Tipos de datos de cada columna

# %%
movies_original.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %% [markdown]
# ### Se realiza una copia para poder realizar el ETL y tener los datos originales para comparar

# %%
movies = movies_original.copy()

# %% [markdown]
# ### Se convierte el Id a tipo de dato entero

# %%
def convertir_id_a_numerico(fila):

    try:
        return int(fila)
    except ValueError:
        return 0

movies['id'] = movies['id'].apply(convertir_id_a_numerico)

# %% [markdown]
# ### Se eliminan Id duplicados

# %%
movies.drop_duplicates(subset='id', inplace=True)

# %% [markdown]
# ### Se eliminan filas sin Id

# %%
movies.drop(movies[movies['id']==0].index, inplace=True)

# %% [markdown]
# ### Se eliminan columnas que no aportan informacion relacionada al proyecto

# %%
movies.drop(['adult', 'video','imdb_id','original_title','poster_path','homepage'], axis=1, inplace=True)

# %% [markdown]
# ### Se verifica el tamaño del dataframe resultante

# %%
movies.shape
# Out:
# (45433, 18)

# %% [markdown]
# ### Vista preliminar del dataframe resultante

# %%
movies
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45461                fa        Rising and falling between a man and woman.
# 45462                tl  An artist struggles to finish his work while a...
# 45463                en  When one of her hits goes wrong, a professiona...
# 45464                en  In a small town live two brothers, one a minis...
# 45465                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies  \
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45461   0.072051                                                 []
# 45462   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45464   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45465   0.163015                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
# [45433 rows x 18 columns]

# %% [markdown]
# ## Se acondiciona credits

# %% [markdown]
# ### Se eliminan duplicados

# %%
credits.drop_duplicates(subset='id', inplace=True)

# %% [markdown]
# ### Se verifica que no queden duplicados

# %%
credits['id'].value_counts()
# Out:
# id
# 862       1
# 74458     1
# 296206    1
# 107308    1
# 16247     1
#          ..
# 32985     1
# 44399     1
# 10138     1
# 32084     1
# 461257    1
# Name: count, Length: 45432, dtype: int64

# %% [markdown]
# ### Se une el dataframe de "credits" al dataframe "movies" por el id en comun

# %%
movies = pd.merge(movies, credits, on='id', how='outer', indicator=True)

# %% [markdown]
# ### Se eliminan nulos en la columna de protagonistas

# %%
movies.dropna(subset=['cast'], inplace=True)

# %% [markdown]
# ### Se elimina columna de verificación del merge

# %%
movies.drop('_merge', axis=1, inplace=True)

# %% [markdown]
# ### Se convierte la columna presupuesto a tipo de dato flotante

# %%
movies['budget'] = pd.to_numeric(movies['budget'], errors='coerce').astype(float)

# %% [markdown]
# ### Se convierte la columna recaudación a tipo de dato flotante

# %%
movies['revenue'] = pd.to_numeric(movies['revenue'], errors='coerce').astype(float)

# %% [markdown]
# ### Se reemplazan valores nulos por ceros en las columnas presupuesto y recaudación

# %%
movies_revenue = movies['revenue']
movies_revenue.fillna(0, inplace=True)
movies_budget = movies['budget']
movies_budget.fillna(0, inplace=True)

# %% [markdown]
# ### Se crea la columna retorno dividiendo la recaudación por el presupuesto de cada pelicula

# %%
def crear_return(fila):
    if fila['budget']==0:
        return 0 
    else:
        return fila['revenue']/fila['budget']

movies['return'] = movies.apply(crear_return, axis=1)

# %% [markdown]
# ### Se verifica si hay nulos en la columna fecha de lanzamiento

# %%
movies['release_date'].isnull().sum()
# Out:
# 87

# %% [markdown]
# ### Se eliminan esos nulos

# %%
movies.dropna(subset=['release_date'], inplace=True)

# %% [markdown]
# ### Se convierte la fecha de lanzamiento a tipo de dato datetime

# %%
movies['release_date'] =pd.to_datetime(movies['release_date'], errors='coerce')

# %% [markdown]
# ### Se crea la columna año de lanzamiento

# %%
movies['release_year']=movies['release_date'].dt.year

# %% [markdown]
# ### Se desanida la columna de pertenencia a una colección

# %%
movies['belongs_to_collection'] = movies['belongs_to_collection'].apply(lambda fila:0 if type(fila)==float else fila)
movies['belongs_to_collection'] = movies['belongs_to_collection'].apply(lambda fila: fila[fila.find("'name'"):fila.find(", 'poster_path'")] if isinstance(fila, str) and 'name' in fila and 'poster_path' in fila else fila)
movies['belongs_to_collection'] = movies['belongs_to_collection'].apply(lambda fila: fila.replace("name': '","")  if isinstance(fila, str) else fila)

# %% [markdown]
# ### Se desanida la columna generos

# %%
def desanidar_generos(fila):
    try:
        list = ast.literal_eval(fila)
        fila_aux = [fila_aux['name'] for fila_aux in list]
        return fila_aux
    except (SyntaxError, ValueError):
        return []
    
movies['genres']=movies['genres'].apply(desanidar_generos)

# %% [markdown]
# ### Se verifica el tipo de dato de la columna generos

# %%
type(movies.loc[0,'genres'])
# Out:
# list

# %% [markdown]
# ### Se desanida la columna companias de producción

# %%
def desanidar_companias(fila):
    try:
        list = ast.literal_eval(fila)
        fila_aux = [fila_aux['name'] for fila_aux in list]
        return fila_aux
    except (SyntaxError, ValueError):
        return []
    
movies['production_companies']=movies['production_companies'].apply(desanidar_companias)

# %% [markdown]
# ### Se desanida la columna paises de producción

# %%
def desanidar_paises(fila):
    try:
        list = ast.literal_eval(fila)
        fila_aux = [fila_aux['name'] for fila_aux in list]
        return fila_aux
    except (SyntaxError, ValueError):
        return []
    
movies['production_countries']=movies['production_countries'].apply(desanidar_paises)

# %% [markdown]
# ### Se desanida la columna de lenguajes

# %%
def desanidar_lenguajes(fila):
    try:
        list = ast.literal_eval(fila)
        fila_aux = [fila_aux['name'] for fila_aux in list]
        return fila_aux
    except (SyntaxError, ValueError):
        return []
    
movies['spoken_languages']=movies['spoken_languages'].apply(desanidar_lenguajes)

# %% [markdown]
# ### Se desanida la columna protagonistas

# %%
def desanidar_personajes(fila):
    try:
        list = ast.literal_eval(fila)
        fila_aux = [fila_aux['character'] for fila_aux in list]
        fila_aux_2 = [fila_aux_2['name'] for fila_aux_2 in list]
        return [fila_aux,fila_aux_2]
    except (SyntaxError, ValueError):
        return []
    
movies['cast']=movies['cast'].apply(desanidar_personajes)

# %% [markdown]
# ### Se crea un diccionario con los actores/actrices

# %%
def crear_diccionario(fila):
    diccionario = {}
    for key, value in zip(fila[0], fila[1]):
        diccionario[key] = value
    return diccionario

# Aplicar la función a la columna del DataFrame y actualizar la columna con el diccionario
movies['cast'] = movies['cast'].apply(crear_diccionario)

# %% [markdown]
# ### Se desanida la columna de equipo de filmación

# %%
def desanidar_equipo(fila):
    try:
        list = ast.literal_eval(fila)
        fila_aux = [fila_aux['job'] for fila_aux in list]
        fila_aux_2 = [fila_aux_2['name'] for fila_aux_2 in list]
        return [fila_aux,fila_aux_2]
    except (SyntaxError, ValueError):
        return []
    
movies['crew']=movies['crew'].apply(desanidar_equipo)

# %% [markdown]
# ### Se crea un diccionario con el equipo de filmación

# %%
def crear_diccionario(fila):
    diccionario = {}
    for key, value in zip(fila[0], fila[1]):
        diccionario[key] = value
    return diccionario

movies['crew'] = movies['crew'].apply(crear_diccionario)

# %% [markdown]
# ### Se crea la columna de directores

# %%
movies['director'] = movies['crew'].apply(lambda x: x.get('Director', ''))

# %% [markdown]
# ### Vista del dataframe con todas las columnas desanidadas y fin del proceso de limpieza

# %%
movies
# Out:
#                   belongs_to_collection      budget  \
# 0                'Toy Story Collection'  30000000.0
# 1                                     0  65000000.0
# 2           'Grumpy Old Men Collection'         0.0
# 3                                     0  16000000.0
# 4      'Father of the Bride Collection'         0.0
# ...                                 ...         ...
# 45427                                 0         0.0
# 45429                                 0         0.0
# 45430                                 0         0.0
# 45431                                 0         0.0
# 45432                                 0         0.0
#
#                              genres      id original_language  \
# 0       [Animation, Comedy, Family]     862                en
# 1      [Adventure, Fantasy, Family]    8844                en
# 2                 [Romance, Comedy]   15602                en
# 3          [Comedy, Drama, Romance]   31357                en
# 4                          [Comedy]   11862                en
# ...                             ...     ...               ...
# 45427      [Drama, Action, Romance]   30840                en
# 45429                       [Drama]  111109                tl
# 45430     [Action, Drama, Thriller]   67758                en
# 45431                            []  227506                en
# 45432                            []  461257                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45427  Yet another version of the classic epic, with ...   5.683753
# 45429  An artist struggles to finish his work while a...   0.178241
# 45430  When one of her hits goes wrong, a professiona...   0.903007
# 45431  In a small town live two brothers, one a minis...   0.003503
# 45432  50 years after decriminalisation of homosexual...   0.163015
#
#                                     production_companies  \
# 0                              [Pixar Animation Studios]
# 1      [TriStar Pictures, Teitler Film, Interscope Co...
# 2                         [Warner Bros., Lancaster Gate]
# 3               [Twentieth Century Fox Film Corporation]
# 4           [Sandollar Productions, Touchstone Pictures]
# ...                                                  ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...
# 45429                                      [Sine Olivia]
# 45430                          [American World Pictures]
# 45431                                        [Yermoliev]
# 45432                                                 []
#
#                                     production_countries release_date  ...  \
# 0                             [United States of America]   1995-10-30  ...
# 1                             [United States of America]   1995-12-15  ...
# 2                             [United States of America]   1995-12-22  ...
# 3                             [United States of America]   1995-12-22  ...
# 4                             [United States of America]   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [Canada, Germany, United Kingdom, United State...   1991-05-13  ...
# 45429                                      [Philippines]   2011-11-17  ...
# 45430                         [United States of America]   2003-08-01  ...
# 45431                                           [Russia]   1917-10-21  ...
# 45432                                   [United Kingdom]   2017-06-09  ...
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45427  Released                                                NaN
# 45429  Released                                                NaN
# 45430  Released                             A deadly game of wits.
# 45431  Released                                                NaN
# 45432  Released                                                NaN
#
#                              title vote_average vote_count  \
# 0                        Toy Story          7.7     5415.0
# 1                          Jumanji          6.9     2413.0
# 2                 Grumpier Old Men          6.5       92.0
# 3                Waiting to Exhale          6.1       34.0
# 4      Father of the Bride Part II          5.7      173.0
# ...                            ...          ...        ...
# 45427                   Robin Hood          5.7       26.0
# 45429          Century of Birthing          9.0        3.0
# 45430                     Betrayal          3.8        6.0
# 45431             Satan Triumphant          0.0        0.0
# 45432                     Queerama          0.0        0.0
#
#                                                     cast  \
# 0      {'Woody (voice)': 'Tom Hanks', 'Buzz Lightyear...
# 1      {'Alan Parrish': 'Robin Williams', 'Samuel Ala...
# 2      {'Max Goldman': 'Walter Matthau', 'John Gustaf...
# 3      {'Savannah 'Vannah' Jackson': 'Whitney Houston...
# 4      {'George Banks': 'Steve Martin', 'Nina Banks':...
# ...                                                  ...
# 45427  {'Sir Robert Hode': 'Patrick Bergin', 'Maid Ma...
# 45429  {'Sister Angela': 'Angel Aquino', 'Homer': 'Pe...
# 45430  {'Emily Shaw': 'Erika Eleniak', 'Det. Mark Win...
# 45431                                {'': 'Vera Orlova'}
# 45432                                                 {}
#
#                                                     crew     return  \
# 0      {'Director': 'John Lasseter', 'Screenplay': 'A...  12.451801
# 1      {'Executive Producer': 'Robert W. Cort', 'Scre...   4.043035
# 2      {'Director': 'Howard Deutch', 'Characters': 'M...   0.000000
# 3      {'Director': 'Forest Whitaker', 'Screenplay': ...   5.090760
# 4      {'Original Music Composer': 'Alan Silvestri', ...   0.000000
# ...                                                  ...        ...
# 45427  {'Director': 'John Irvin', 'Writer': 'John McG...   0.000000
# 45429  {'Director': 'Lav Diaz', 'Writer': 'Lav Diaz',...   0.000000
# 45430  {'Director': 'Mark L. Lester', 'Screenplay': '...   0.000000
# 45431  {'Director': 'Yakov Protazanov', 'Producer': '...   0.000000
# 45432                      {'Director': 'Daisy Asquith'}   0.000000
#
#       release_year          director
# 0             1995     John Lasseter
# 1             1995      Joe Johnston
# 2             1995     Howard Deutch
# 3             1995   Forest Whitaker
# 4             1995     Charles Shyer
# ...            ...               ...
# 45427         1991        John Irvin
# 45429         2011          Lav Diaz
# 45430         2003    Mark L. Lester
# 45431         1917  Yakov Protazanov
# 45432         2017     Daisy Asquith
#
# [45345 rows x 23 columns]

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # Carga

# %% [markdown]
# ### Para la carga de datos se tomaran en cuenta solo las columnas que van a ser usadas posteriormente en el proyecto, el resto se descarta

# %% [markdown]
# ### Se eliminan columnas que no se utilizaran en el EDA ni en las funciones para la API

# %%
movies.drop(['belongs_to_collection','original_language','production_companies','production_countries','spoken_languages','status','crew'], inplace=True, axis=1)

# %% [markdown]
# ### Se guarda el dataframe en formato parquet para obtener un mejor rendimiento al realizar la API

# %%
fastparquet.write('/work/movies_with_credits.parquet', movies)

# %% [markdown]
# ### Se guarda el mismo dataframe en formato csv para realizar el EDA ya que al hacerlo con formato parquet surgen errores con la librería seaborn

# %%
movies.to_csv('movies_with_credits.csv', index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=01743208-f339-48d2-82a4-bdc6d181301e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
